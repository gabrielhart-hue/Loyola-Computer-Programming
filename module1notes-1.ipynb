# %%
x = 12
y = 7.2
z = "wow"
print(x)
print(y)
print(z)
# Out:
# 12
# 7.2
# wow

# %% [markdown]
# # i created three variable, their names are x,y, and z. x is an interger, y is a float, z is a string
# # i used the orint command to print them.

# %%
jar1 = 5
jar2 = 10
hello = "hello"
print(jar1 + jar2 + hello)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 4
#       2 jar2 = 10
#       3 hello = "hello"
# ----> 4 print(jar1 + jar2 + hello)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# # this code does not work because you can't add integers and strings.

# %%
jar1 = 5
jar2 = 10
print(jar2)

jar2 = jar1
print(jar2)
# Out:
# 10
# 5

# %% [markdown]
# whatever is on the left of the equal sign gets set to the value on the right of the equal sign.

# %%
name = "John"
age = 8
print("My name is" ,name, "and I am" ,age, "years old!")
# Out:
# My name is John and I am 8 years old!

# %% [markdown]
# # when i am printing multiple things such as string literals and variables all at once, i separate between them the print statement with commas.

# %%
name = "Gabriel"

print(name.upper())
print(name.lower())
print(name.title())
# Out:
# GABRIEL
# gabriel
# Gabriel

# %% [markdown]
# # i set name = gabriel then print it upper case, lower case, and title. These are methods.

# %% [markdown]
# ### print is a function, i use it by itself and I put what i want to print in the parenthesis
# ### .upper() is a method. I use it on a string. meaning i create a string, and then i call .upper() on the string that I want to convert to uppercase

# %%
my_life = "splendid" 

print(my_life.title())
print(my_life.upper())
print(my_life.lower())
# Out:
# Splendid
# SPLENDID
# splendid

# %%
fname = "Gabriel"
lname = "Hart"
full_name = f"{fname} A {lname}"
print(fname, lname)
print(full_name)
print(f"Hello, {fname.title()}!")
# Out:
# Gabriel Hart
# Gabriel A Hart
# Hello, Gabriel!

# %% [markdown]
# ### To combine two strings you can put an f right outside the quotations and inside the quotes but inside the braces you put the variable names and separate them with a space.

# %%
print("grocery list:\n\t-apples\n\t-bananas\n\t-milk\n\t-celery\n\t-peanut\n\t-butter\n\t-butter\n\t-bread")
# Out:
# grocery list:
# 	-apples
# 	-bananas
# 	-milk
# 	-celery
# 	-peanut
# 	-butter
# 	-butter
# 	-bread

# %% [markdown]
# ### \n puts the items in a list and \t puts a tab infront of the items. the word at the start is the name of the list.

# %%
# there are three methods to clear whitespace: rstrip(), lstrip(), and strip()
name = " Gabriel "
name_cleaned = name.strip().upper()
print(name)
print(name_cleaned)
# Out:
#  Gabriel
# GABRIEL

# %% [markdown]
# #### there are three methods to clear whitespace are rstrip(), lstrip(), and strip()

# %%
name = input("Enter your name")
print(name)
# Out:
# Gabriel

# %% [markdown]
# ### if i want input from the user, I can use the input function and in the parenthesis, in quotes, I will write the message to the user. I will store the result in a variable, in this case my variable is name.
