# %% [markdown]
# ### Module 2 Notes: Lists

# %%
fav_words = ["dog", "mouse", "tree", "brick", "log"]
print(fav_words)
print(fav_words[0])
print(fav_words[2])
#go to the last item in your list and print out an all caps version.
print(fav_words[-1])
print(fav_words[4].upper())
print(fav_words[1].title())
print("One of my favorite words is",fav_words[3])
my_sentence = f"One of my favorite words is {fav_words[3]}."
print(my_sentence)
length = len(fav_words)

print(length)
print(len(fav_words))
# Out:
# ['dog', 'mouse', 'tree', 'brick', 'log']
# dog
# tree
# log
# LOG
# Mouse
# One of my favorite words is brick
# One of my favorite words is brick.
# 5
# 5

# %% [markdown]
# # Every item in a list has a location starting at zero. We can also start from the end with -1. The location is referred to as an index. So the first item in a list is at index 0. We can use the items in the list accirdung to their type. If the items are strings, we can call string methods on them. If they are numbers, we can do math with them. The way we access a particular item in a list is nam_of_list[index]. There is a len fuction that will tell us how long the list is.

# %%
birthday = ["09", "05", "09"]
bday_as_string = f"I was born in the year {birthday[2]} on the day {birthday[1]} in the month {birthday[0]}"
print(bday_as_string)
# Out:
# I was born in the year 09 on the day 05 in the month 09

# %%
siblings = ["jerry", "mike" , "fred" , "mary"]
order_of_siblings = f"my favorite sibling is {siblings[2]} , second is {siblings[1]} ,third is {siblings[0]} ,last is {siblings[3]}"
print(order_of_siblings)
siblings.append("bear")
siblings[0] = "joey"
print(siblings)
# Out:
# my favorite sibling is fred , second is mike ,third is jerry ,last is mary
# ['joey', 'mike', 'fred', 'mary', 'bear']

# %%
grades = [23 , 98 , 12 , 130 , 87]
grades.insert(2, 100)
print(grades)
print((grades[0] + grades[1] + grades[2] + grades[3]+ grades[4])/5)
# Out:
# [23, 98, 100, 12, 130, 87]
# 72.6

# %% [markdown]
# # I can change the value of an itme in the list by resetting it. for example my_list[1] = "new value". I can also use methods on lists. Some methods I can use are .append() and .insert(). Append adds an item to the end of the list. Insert adds an item somewher in the list and shifts everything down to the right. Append takes one parameter which means i put one value in () and that value is the thing I'm adding to the list. Insert takes two parameters. The first is the location, the seond is the item to insert at that location.

# %%
activities = ["jump", "walk", "run", "skip", "sleep", "eat"]
print(activities)
activities.remove("jump")
activities.pop(3)
print(activities)
# Out:
# ['jump', 'walk', 'run', 'skip', 'sleep', 'eat']
# ['walk', 'run', 'skip', 'eat']

# %% [markdown]
# ## pop requires me to know the index of the value i'm trying to remove wheras remove requires me to know the exact vaule

# %%
numbers = [3, 5, 8, 10, 11, 28, 42, 77, 101, 108, 2002]
numbers[2] = 1
print(numbers)
numbers.insert(2,50)
numbers.remove(108)
numbers.append(100)
print(numbers)
numbers.pop(-2)
print(numbers)
numbers.pop(5)
print(numbers)
del(numbers[1])
print(numbers)
# Out:
# [3, 5, 1, 10, 11, 28, 42, 77, 101, 108, 2002]
# [3, 5, 50, 1, 10, 11, 28, 42, 77, 101, 2002, 100]
# [3, 5, 50, 1, 10, 11, 28, 42, 77, 101, 100]
# [3, 5, 50, 1, 10, 28, 42, 77, 101, 100]
# [3, 50, 1, 10, 28, 42, 77, 101, 100]

# %%
places = ["forest", "beach" , "school", "tundra" ,"house"]
places.append("hello")
print(places)
places.insert(3,1)
print(places)
del(places[1])
places.pop(1)
places.remove("hello")
y = places.pop()
print(f"The last word in my list was {y}.")
# Out:
# ['forest', 'beach', 'school', 'tundra', 'house', 'hello']
# ['forest', 'beach', 'school', 1, 'tundra', 'house', 'hello']
# The last word in my list was house.

# %% [markdown]
# # pop has three functionalities. 1) it can remove by index for example: my_list.pop(1) 2. it can store the value it deletes for a second so you can store it in a vartiable. for example y = my_list. pop(1) 3. it can make the executive decision to deleete the last item if you don't give it any additional value. For example my_list.pop()

# %%
elements = ["hydrogen", "helium", "lithium","beryllium", "iron", "aluminum", "boron", "rutherfordium", "carbon" ]
print(elements)
elements.sort()
elements.reverse()
print(elements)

flowers = ["rose", "lily", "tulip", "sunflower", "lupine", "orchid", "lavender"]
print(sorted(flowers))
print(flowers)
print("rose" in flowers)
# Out:
# ['hydrogen', 'helium', 'lithium', 'beryllium', 'iron', 'aluminum', 'boron', 'rutherfordium', 'carbon']
# ['rutherfordium', 'lithium', 'iron', 'hydrogen', 'helium', 'carbon', 'boron', 'beryllium', 'aluminum']
# ['lavender', 'lily', 'lupine', 'orchid', 'rose', 'sunflower', 'tulip']
# ['rose', 'lily', 'tulip', 'sunflower', 'lupine', 'orchid', 'lavender']
# True

# %% [markdown]
# ## .sort() is a method that will change the order of the list to be in alphabetical order .reverse() reverses the order of a list. Both of these fundamentally change the order of the list permanently. on the other hand, sorted() is a function that can temporarily sort a list with permanently changing it

# %%
colors = ["red", "blue", "green"]
colors[0] = colors[0].title()
colors[1] = colors[1].title()
colors[2] = colors[2].title()
print(colors)
# Out:
# ['Red', 'Blue', 'Green']

# %%
teams = ["chargers", "rams", "lakers"]
print(teams)
print(teams[0])
print(teams[1])
for thing in teams:
    print(thing)
    print("hello")
    print("Gabriel")
print("loyola")
print("goodbye")
for thing in teams:
    print(f"The {thing.title()} are my favorite!")
# Out:
# ['chargers', 'rams', 'lakers']
# chargers
# rams
# chargers
# hello
# Gabriel
# rams
# hello
# Gabriel
# lakers
# hello
# Gabriel
# loyola
# goodbye
# The Chargers are my favorite!
# The Rams are my favorite!
# The Lakers are my favorite!

# %%
songs = ["ABC's", "testify", "rather lie", "back in the day", "twinkle twinkle little star"]
for song in songs:
    print(f"I like {songs}!")
print("I like these songs.")
# Out:
# I like ["ABC's", 'testify', 'rather lie', 'back in the day', 'twinkle twinkle little star']!
# I like ["ABC's", 'testify', 'rather lie', 'back in the day', 'twinkle twinkle little star']!
# I like ["ABC's", 'testify', 'rather lie', 'back in the day', 'twinkle twinkle little star']!
# I like ["ABC's", 'testify', 'rather lie', 'back in the day', 'twinkle twinkle little star']!
# I like ["ABC's", 'testify', 'rather lie', 'back in the day', 'twinkle twinkle little star']!
# I like these songs.

# %%
numbers = list(range(1,10,))
print(numbers)
numbers = list(range(0,251, 7))
print(numbers)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# [0, 7, 14, 21, 28, 35, 42, 49, 56, 63, 70, 77, 84, 91, 98, 105, 112, 119, 126, 133, 140, 147, 154, 161, 168, 175, 182, 189, 196, 203, 210, 217, 224, 231, 238, 245]

# %% [markdown]
# ## When I I use a for loop, the word asfter for is a moving variable. It will get set to a different item in the list every time the loop runs. That word, in my example song, does not exist outdside of the loop. When I refer to things being inside and outside og the loop, I'm refferring to whether or not something is indented below it or not. We learned two more funcitions. Range gives me numbers from the first parameter, up to but not including the seond parameter. If I add a third, that will be the increment. The list function builds a list with whatever parameter I give it.

# %%
perfect_squares = []
for i in range(1,11):
    perfect_squares.append(i**2)
print(perfect_squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %% [markdown]
# ## When I use a for loop, the i (or whaterver variable i pute after the word for) changes every time the loop runs. I can use that i elsewhere in my loop if necessary.

# %%
fish = ["salmon", "tuna", "trout", "rooster", "goldfish", "dolphin"]
print(fish[1:4])
# Out:
# ['tuna', 'trout', 'rooster']
